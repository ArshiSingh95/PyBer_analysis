# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
points_list = [1,6,2,4]
plt.plot(points_list, marker = "o")

plt.xlabel("index")

plt.xticks([0,1,2,3,4])



plt.show()
